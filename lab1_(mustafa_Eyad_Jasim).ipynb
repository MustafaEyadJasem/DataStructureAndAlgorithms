# %% [markdown]
# <a href="https://colab.research.google.com/github/MustafaEyadJasem/DataStructureAndAlgorithms/blob/master/lab1_(mustafa_Eyad_Jasim).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df = pd.read_csv('Clinical Data_Discovery_Cohort.csv')
df.head()
# Out:
#    PatientID Specimen date Dead or Alive Date of Death Date of Last Follow Up  \
# 0          1     3/17/2003          Dead     2/24/2010              2/24/2010
# 1          2     6/17/2003          Dead    11/12/2004             11/12/2004
# 2          3      9/9/2003          Dead      8/1/2009               8/1/2009
# 3          4    10/14/2003          Dead    12/29/2006             12/29/2006
# 4          5     12/1/2003          Dead     1/31/2004              1/31/2004
#
#   sex race    Stage  Event  Time
# 0   F    B  pT2N2MX      1  2536
# 1   M    W   T2N2MX      1   514
# 2   F    B   T2N1MX      1  2153
# 3   M    W  pT2NOMX      1  1172
# 4   F    W   T2NOMX      1    61

# %%
df= pd.read_csv('Clinical Data_Discovery_Cohort.csv',
                header=0,
                usecols=['PatientID','sex','Dead or Alive'])
df.head()
# Out:
#    PatientID Dead or Alive sex
# 0          1          Dead   F
# 1          2          Dead   M
# 2          3          Dead   F
# 3          4          Dead   M
# 4          5          Dead   F

# %%
df= pd.read_csv('Clinical Data_Discovery_Cohort.csv',
                sep = '[ , ]',##comma sepration in excel
                engine='python')
df.head()
# Out:
#    PatientID    Specimen  date        Dead          or Alive Date       of  \
# 0          1   3/17/2003  Dead   2/24/2010   2/24/2010     F    B  pT2N2MX
# 1          2   6/17/2003  Dead  11/12/2004  11/12/2004     M    W   T2N2MX
# 2          3    9/9/2003  Dead    8/1/2009    8/1/2009     F    B   T2N1MX
# 3          4  10/14/2003  Dead  12/29/2006  12/29/2006     M    W  pT2NOMX
# 4          5   12/1/2003  Dead   1/31/2004   1/31/2004     F    W   T2NOMX
#
#   Death Date.1  of.1  Last  Follow  Up  sex  race  Stage  Event  Time
# 0     1   2536   NaN   NaN     NaN NaN  NaN   NaN    NaN    NaN   NaN
# 1     1    514   NaN   NaN     NaN NaN  NaN   NaN    NaN    NaN   NaN
# 2     1   2153   NaN   NaN     NaN NaN  NaN   NaN    NaN    NaN   NaN
# 3     1   1172   NaN   NaN     NaN NaN  NaN   NaN    NaN    NaN   NaN
# 4     1     61   NaN   NaN     NaN NaN  NaN   NaN    NaN    NaN   NaN

# %%
df= pd.read_csv('Clinical Data_Discovery_Cohort.csv',
                header= 0,
                index_col=['PatientID','sex'],
                usecols=['PatientID','sex','Dead or Alive'],
                nrows=4)#nrows=3: limits of read operation first three rows of dataset.
df.head()
#
# Out:
#               Dead or Alive
# PatientID sex
# 1         F            Dead
# 2         M            Dead
# 3         F            Dead
# 4         M            Dead
